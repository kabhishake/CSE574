# %%
"I (We) certify that the code and data in this assignment were generated independently, using only the tools and resources defined in the course and that I (we) did not receive any external help, coaching or contributions during the production of this work."
# Out:
# 'I (We) certify that the code and data in this assignment were generated independently, using only the tools and resources defined in the course and that I (we) did not receive any external help, coaching or contributions during the production of this work.'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_csv("income_dataset.csv")

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum(axis=0)
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df_categorical = df.select_dtypes(include=['object'])

df_categorical.nunique()
# Out:
# workclass          9
# education         16
# marital.status     7
# occupation        15
# relationship       6
# race               5
# sex                2
# native.country    42
# income             2
# dtype: int64

# %%
# Lets explore the categorical/string columns in more detail
# Note that there are some '?' values which must be missing values

for col in df_categorical:
    print(col, ": ", df[col].unique())
# Out:
# workclass :  ['?' 'Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc' 'Self-emp-inc'
#  'Local-gov' 'Without-pay' 'Never-worked']
# education :  ['HS-grad' 'Some-college' '7th-8th' '10th' 'Doctorate' 'Prof-school'
#  'Bachelors' 'Masters' '11th' 'Assoc-acdm' 'Assoc-voc' '1st-4th' '5th-6th'
#  '12th' '9th' 'Preschool']
# marital.status :  ['Widowed' 'Divorced' 'Separated' 'Never-married' 'Married-civ-spouse'
#  'Married-spouse-absent' 'Married-AF-spouse']
# occupation :  ['?' 'Exec-managerial' 'Machine-op-inspct' 'Prof-specialty'
#  'Other-service' 'Adm-clerical' 'Craft-repair' 'Transport-moving'
#  'Handlers-cleaners' 'Sales' 'Farming-fishing' 'Tech-support'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# relationship :  ['Not-in-family' 'Unmarried' 'Own-child' 'Other-relative' 'Husband' 'Wife']
# race :  ['White' 'Black' 'Asian-Pac-Islander' 'Other' 'Amer-Indian-Eskimo']
# sex :  ['Female' 'Male']
# native.country :  ['United-States' '?' 'Mexico' 'Greece' 'Vietnam' 'China' 'Taiwan' 'India'
#  'Philippines' 'Trinadad&Tobago' 'Canada' 'South' 'Holand-Netherlands'
#  'Puerto-Rico' 'Poland' 'Iran' 'England' 'Germany' 'Italy' 'Japan' 'Hong'
#  'Honduras' 'Cuba' 'Ireland' 'Cambodia' 'Peru' 'Nicaragua'
#  'Dominican-Republic' 'Haiti' 'El-Salvador' 'Hungary' 'Columbia'
#  'Guatemala' 'Jamaica' 'Ecuador' 'France' 'Yugoslavia' 'Scotland'
#  'Portugal' 'Laos' 'Thailand' 'Outlying-US(Guam-USVI-etc)']
# income :  ['<=50K' '>50K']

# %%
# Replacing ? with NaN

df.replace("?", np.nan, inplace = True)
df.isnull().any(axis=1).sum()
# Out:
# 2399

# %%
# Handling missing values. 
# Since only few rows (about 7%) are containing missing values we can remove them
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income
# 1          4356              18  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K
# 5          3770              45  United-States  <=50K
# 6          3770              40  United-States  <=50K

# %%
## EDA plots

# %%
# First univariate analysis - histplots for continuous and countplots for categorical 

fig, ax = plt.subplots(3, 2, figsize=(15, 10))

sns.histplot(x="age", data=df, kde=True, ax=ax[0, 0])
sns.histplot(x="fnlwgt", data=df, kde=True, ax=ax[0, 1])
sns.histplot(x="capital.gain", data=df, kde=True, ax=ax[1, 0])
sns.histplot(x="capital.loss", data=df, kde=True, ax=ax[1, 1])
sns.histplot(x="capital.loss", data=df, kde=True, ax=ax[2, 0])

plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(16, 14), constrained_layout=True)

sns.countplot(x='workclass', data=df, ax=ax[0,0])
ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(), rotation=90, fontsize=10)

sns.countplot(x='education', data=df, ax=ax[0,1])
ax[0,1].set_xticklabels(ax[0,1].get_xticklabels(), rotation=90, fontsize=10)

sns.countplot(x='marital.status', data=df, ax=ax[1,0])
ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(), rotation=90, fontsize=10)

sns.countplot(x='occupation', data=df, ax=ax[1,1])
ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(), rotation=90, fontsize=10)

sns.countplot(x='relationship', data=df, ax=ax[2,0])
ax[2,0].set_xticklabels(ax[2,0].get_xticklabels(), rotation=90, fontsize=10)

sns.countplot(x='native.country', data=df, ax=ax[2,1])
ax[2,1].set_xticklabels(ax[2,1].get_xticklabels(), rotation=90, fontsize=10)

plt.show()

# %%
# Bi-variate analysis

sns.pairplot(df, hue="income", corner=True)
plt.show()

# %%
sns.heatmap(df.corr())
plt.show()

# negligible correlation between variables

# %%
# Multivariate

# Impact of workclass and sex on income using countplots

plt.figure(figsize=(10,6))
ax = sns.catplot(x='workclass', hue='sex', col='income', data=df, kind='count')
ax.set_xticklabels(rotation=90, fontsize=10)
plt.show()

# %%
# Impact of education on income

plt.figure(figsize=(10,6))
ax = sns.countplot(x='education', hue='income', data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, fontsize=10)
plt.show()

# %%
# Building NN model

# %%
# checking if we need both education and education_num columns

for edu in df['education'].unique():
    print(edu,":", df[df['education'] == edu]["education.num"].nunique())
    
# Note that 'education.num' is unique for each value of 'education'. 
# It also appears to be ordinal which makes sense. 
# Thus, we can remove 'education' column

df = df.drop(columns = ['education'])
# Out:
# HS-grad : 1
# 7th-8th : 1
# Some-college : 1
# 10th : 1
# Doctorate : 1
# Prof-school : 1
# Bachelors : 1
# Masters : 1
# 11th : 1
# Assoc-voc : 1
# 1st-4th : 1
# 5th-6th : 1
# Assoc-acdm : 1
# 12th : 1
# 9th : 1
# Preschool : 1

# %%
# One-hot encoding the categorical variables to use in NN model

df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 1   82  132870              9             0          4356              18
# 3   54  140359              4             0          3900              40
# 4   41  264663             10             0          3900              40
# 5   34  216864              9             0          3770              45
# 6   38  150601              6             0          3770              40
#
#    workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# 1                    0                  1                       0
# 3                    0                  1                       0
# 4                    0                  1                       0
# 5                    0                  1                       0
# 6                    0                  1                       0
#
#    workclass_Self-emp-not-inc  ...  native.country_Puerto-Rico  \
# 1                           0  ...                           0
# 3                           0  ...                           0
# 4                           0  ...                           0
# 5                           0  ...                           0
# 6                           0  ...                           0
#
#    native.country_Scotland  native.country_South  native.country_Taiwan  \
# 1                        0                     0                      0
# 3                        0                     0                      0
# 4                        0                     0                      0
# 5                        0                     0                      0
# 6                        0                     0                      0
#
#    native.country_Thailand  native.country_Trinadad&Tobago  \
# 1                        0                               0
# 3                        0                               0
# 4                        0                               0
# 5                        0                               0
# 6                        0                               0
#
#    native.country_United-States  native.country_Vietnam  \
# 1                             1                       0
# 3                             1                       0
# 4                             1                       0
# 5                             1                       0
# 6                             1                       0
#
#    native.country_Yugoslavia  income_>50K
# 1                          0            0
# 3                          0            0
# 4                          0            0
# 5                          0            0
# 6                          0            0
#
# [5 rows x 82 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 1 to 32560
# Data columns (total 82 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        30162 non-null  int64
#  1   fnlwgt                                     30162 non-null  int64
#  2   education.num                              30162 non-null  int64
#  3   capital.gain                               30162 non-null  int64
#  4   capital.loss                               30162 non-null  int64
#  5   hours.per.week                             30162 non-null  int64
#  6   workclass_Local-gov                        30162 non-null  uint8
#  7   workclass_Private                          30162 non-null  uint8
#  8   workclass_Self-emp-inc                     30162 non-null  uint8
#  9   workclass_Self-emp-not-inc                 30162 non-null  uint8
#  10  workclass_State-gov                        30162 non-null  uint8
#  11  workclass_Without-pay                      30162 non-null  uint8
#  12  marital.status_Married-AF-spouse           30162 non-null  uint8
#  13  marital.status_Married-civ-spouse          30162 non-null  uint8
#  14  marital.status_Married-spouse-absent       30162 non-null  uint8
#  15  marital.status_Never-married               30162 non-null  uint8
#  16  marital.status_Separated                   30162 non-null  uint8
#  17  marital.status_Widowed                     30162 non-null  uint8
#  18  occupation_Armed-Forces                    30162 non-null  uint8
#  19  occupation_Craft-repair                    30162 non-null  uint8
#  20  occupation_Exec-managerial                 30162 non-null  uint8
#  21  occupation_Farming-fishing                 30162 non-null  uint8
#  22  occupation_Handlers-cleaners               30162 non-null  uint8
#  23  occupation_Machine-op-inspct               30162 non-null  uint8
#  24  occupation_Other-service                   30162 non-null  uint8
#  25  occupation_Priv-house-serv                 30162 non-null  uint8
#  26  occupation_Prof-specialty                  30162 non-null  uint8
#  27  occupation_Protective-serv                 30162 non-null  uint8
#  28  occupation_Sales                           30162 non-null  uint8
#  29  occupation_Tech-support                    30162 non-null  uint8
#  30  occupation_Transport-moving                30162 non-null  uint8
#  31  relationship_Not-in-family                 30162 non-null  uint8
#  32  relationship_Other-relative                30162 non-null  uint8
#  33  relationship_Own-child                     30162 non-null  uint8
#  34  relationship_Unmarried                     30162 non-null  uint8
#  35  relationship_Wife                          30162 non-null  uint8
#  36  race_Asian-Pac-Islander                    30162 non-null  uint8
#  37  race_Black                                 30162 non-null  uint8
#  38  race_Other                                 30162 non-null  uint8
#  39  race_White                                 30162 non-null  uint8
#  40  sex_Male                                   30162 non-null  uint8
#  41  native.country_Canada                      30162 non-null  uint8
#  42  native.country_China                       30162 non-null  uint8
#  43  native.country_Columbia                    30162 non-null  uint8
#  44  native.country_Cuba                        30162 non-null  uint8
#  45  native.country_Dominican-Republic          30162 non-null  uint8
#  46  native.country_Ecuador                     30162 non-null  uint8
#  47  native.country_El-Salvador                 30162 non-null  uint8
#  48  native.country_England                     30162 non-null  uint8
#  49  native.country_France                      30162 non-null  uint8
#  50  native.country_Germany                     30162 non-null  uint8
#  51  native.country_Greece                      30162 non-null  uint8
#  52  native.country_Guatemala                   30162 non-null  uint8
#  53  native.country_Haiti                       30162 non-null  uint8
#  54  native.country_Holand-Netherlands          30162 non-null  uint8
#  55  native.country_Honduras                    30162 non-null  uint8
#  56  native.country_Hong                        30162 non-null  uint8
#  57  native.country_Hungary                     30162 non-null  uint8
#  58  native.country_India                       30162 non-null  uint8
#  59  native.country_Iran                        30162 non-null  uint8
#  60  native.country_Ireland                     30162 non-null  uint8
#  61  native.country_Italy                       30162 non-null  uint8
#  62  native.country_Jamaica                     30162 non-null  uint8
#  63  native.country_Japan                       30162 non-null  uint8
#  64  native.country_Laos                        30162 non-null  uint8
#  65  native.country_Mexico                      30162 non-null  uint8
#  66  native.country_Nicaragua                   30162 non-null  uint8
#  67  native.country_Outlying-US(Guam-USVI-etc)  30162 non-null  uint8
#  68  native.country_Peru                        30162 non-null  uint8
#  69  native.country_Philippines                 30162 non-null  uint8
#  70  native.country_Poland                      30162 non-null  uint8
#  71  native.country_Portugal                    30162 non-null  uint8
#  72  native.country_Puerto-Rico                 30162 non-null  uint8
#  73  native.country_Scotland                    30162 non-null  uint8
#  74  native.country_South                       30162 non-null  uint8
#  75  native.country_Taiwan                      30162 non-null  uint8
#  76  native.country_Thailand                    30162 non-null  uint8
#  77  native.country_Trinadad&Tobago             30162 non-null  uint8
#  78  native.country_United-States               30162 non-null  uint8
#  79  native.country_Vietnam                     30162 non-null  uint8
#  80  native.country_Yugoslavia                  30162 non-null  uint8
#  81  income_>50K                                30162 non-null  uint8
# dtypes: int64(6), uint8(76)
# memory usage: 5.0 MB

# %%
# min-max scaling of the continuous features

continuous_columns = ["age", "fnlwgt", "capital.loss", "capital.gain", "education.num", "hours.per.week"]

for col in continuous_columns:
    df[col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, :-1]
y = df["income_>50K"]
# Split Train and Test Datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
#Input features to the first hidden layer of 128 neurons, followed by two additional hidden layers of 256 neurons.
#There’s a 1-neuron output layer at the end. Hidden layers use ReLU as the activation function, and the output layer uses Sigmoid

import tensorflow as tf

tf.random.set_seed(42)


model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.03),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

history = model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3890 - accuracy: 0.8173 - precision: 0.6750 - recall: 0.5233
# Epoch 2/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3580 - accuracy: 0.8347 - precision: 0.7118 - recall: 0.5726
# Epoch 3/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3454 - accuracy: 0.8396 - precision: 0.7347 - recall: 0.5639
# Epoch 4/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3436 - accuracy: 0.8405 - precision: 0.7207 - recall: 0.5941
# Epoch 5/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3560 - accuracy: 0.8368 - precision: 0.7121 - recall: 0.5866
# Epoch 6/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3734 - accuracy: 0.8372 - precision: 0.7138 - recall: 0.5860
# Epoch 7/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3438 - accuracy: 0.8407 - precision: 0.7238 - recall: 0.5900
# Epoch 8/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3403 - accuracy: 0.8397 - precision: 0.7199 - recall: 0.5904
# Epoch 9/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3417 - accuracy: 0.8402 - precision: 0.7248 - recall: 0.5850
# Epoch 10/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3407 - accuracy: 0.8412 - precision: 0.7234 - recall: 0.5935
# Epoch 11/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3367 - accuracy: 0.8409 - precision: 0.7229 - recall: 0.5929
# Epoch 12/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3384 - accuracy: 0.8427 - precision: 0.7255 - recall: 0.5996
# Epoch 13/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3402 - accuracy: 0.8387 - precision: 0.7222 - recall: 0.5801
# Epoch 14/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3353 - accuracy: 0.8432 - precision: 0.7289 - recall: 0.5967
# Epoch 15/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3344 - accuracy: 0.8434 - precision: 0.7288 - recall: 0.5981
# Epoch 16/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3350 - accuracy: 0.8421 - precision: 0.7267 - recall: 0.5935
# Epoch 17/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3364 - accuracy: 0.8436 - precision: 0.7302 - recall: 0.5971
# Epoch 18/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3472 - accuracy: 0.8453 - precision: 0.7341 - recall: 0.6008
# Epoch 19/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3336 - accuracy: 0.8450 - precision: 0.7377 - recall: 0.5927
# Epoch 20/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3448 - accuracy: 0.8413 - precision: 0.7292 - recall: 0.5845
# Epoch 21/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.4183 - accuracy: 0.8463 - precision: 0.7386 - recall: 0.5993
# Epoch 22/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3358 - accuracy: 0.8427 - precision: 0.7318 - recall: 0.5886
# Epoch 23/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3319 - accuracy: 0.8421 - precision: 0.7302 - recall: 0.5874
# Epoch 24/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3278 - accuracy: 0.8433 - precision: 0.7288 - recall: 0.5977
# Epoch 25/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3297 - accuracy: 0.8464 - precision: 0.7386 - recall: 0.6000
# Epoch 26/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3482 - accuracy: 0.8449 - precision: 0.7384 - recall: 0.5910
# Epoch 27/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3285 - accuracy: 0.8458 - precision: 0.7372 - recall: 0.5985
# Epoch 28/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3562 - accuracy: 0.8430 - precision: 0.7308 - recall: 0.5923
# Epoch 29/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3266 - accuracy: 0.8449 - precision: 0.7349 - recall: 0.5967
# Epoch 30/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3257 - accuracy: 0.8458 - precision: 0.7368 - recall: 0.5993
# Epoch 31/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3317 - accuracy: 0.8461 - precision: 0.7407 - recall: 0.5945
# Epoch 32/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3660 - accuracy: 0.8474 - precision: 0.7434 - recall: 0.5981
# Epoch 33/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3267 - accuracy: 0.8454 - precision: 0.7380 - recall: 0.5947
# Epoch 34/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3252 - accuracy: 0.8472 - precision: 0.7376 - recall: 0.6064
# Epoch 35/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3289 - accuracy: 0.8445 - precision: 0.7333 - recall: 0.5969
# Epoch 36/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3352 - accuracy: 0.8469 - precision: 0.7414 - recall: 0.5981
# Epoch 37/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3232 - accuracy: 0.8463 - precision: 0.7356 - recall: 0.6044
# Epoch 38/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3225 - accuracy: 0.8473 - precision: 0.7407 - recall: 0.6020
# Epoch 39/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3258 - accuracy: 0.8462 - precision: 0.7395 - recall: 0.5967
# Epoch 40/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3299 - accuracy: 0.8423 - precision: 0.7302 - recall: 0.5886
# Epoch 41/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3234 - accuracy: 0.8451 - precision: 0.7296 - recall: 0.6073
# Epoch 42/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3337 - accuracy: 0.8468 - precision: 0.7412 - recall: 0.5979
# Epoch 43/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3999 - accuracy: 0.8457 - precision: 0.7464 - recall: 0.5825
# Epoch 44/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3476 - accuracy: 0.8442 - precision: 0.7354 - recall: 0.5918
# Epoch 45/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3340 - accuracy: 0.8437 - precision: 0.7332 - recall: 0.5921
# Epoch 46/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3448 - accuracy: 0.8443 - precision: 0.7377 - recall: 0.5882
# Epoch 47/100
# 632/632 [==============================] - 1s 2ms/step - loss: 0.3279 - accuracy: 0.8452 - precision: 0.7327 - recall: 0.6024
# Epoch 48/100
# 632/632 [==============================] - 1s 2ms/step - loss: 0.3244 - accuracy: 0.8491 - precision: 0.7393 - recall: 0.6150
# Epoch 49/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3195 - accuracy: 0.8509 - precision: 0.7445 - recall: 0.6170
# Epoch 50/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3391 - accuracy: 0.8475 - precision: 0.7389 - recall: 0.6060
# Epoch 51/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3250 - accuracy: 0.8475 - precision: 0.7385 - recall: 0.6069
# Epoch 52/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3336 - accuracy: 0.8455 - precision: 0.7347 - recall: 0.6006
# Epoch 53/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3359 - accuracy: 0.8496 - precision: 0.7425 - recall: 0.6127
# Epoch 54/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3332 - accuracy: 0.8466 - precision: 0.7402 - recall: 0.5983
# Epoch 55/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3220 - accuracy: 0.8527 - precision: 0.7482 - recall: 0.6219
# Epoch 56/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3753 - accuracy: 0.8464 - precision: 0.7379 - recall: 0.6010
# Epoch 57/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3234 - accuracy: 0.8495 - precision: 0.7437 - recall: 0.6099
# Epoch 58/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3267 - accuracy: 0.8479 - precision: 0.7432 - recall: 0.6014
# Epoch 59/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3537 - accuracy: 0.8447 - precision: 0.7354 - recall: 0.5945
# Epoch 60/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3287 - accuracy: 0.8443 - precision: 0.7319 - recall: 0.5981
# Epoch 61/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3261 - accuracy: 0.8472 - precision: 0.7375 - recall: 0.6066
# Epoch 62/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3240 - accuracy: 0.8478 - precision: 0.7387 - recall: 0.6085
# Epoch 63/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3168 - accuracy: 0.8522 - precision: 0.7448 - recall: 0.6249
# Epoch 64/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3220 - accuracy: 0.8508 - precision: 0.7490 - recall: 0.6093
# Epoch 65/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3321 - accuracy: 0.8458 - precision: 0.7385 - recall: 0.5963
# Epoch 66/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3263 - accuracy: 0.8470 - precision: 0.7423 - recall: 0.5973
# Epoch 67/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3237 - accuracy: 0.8468 - precision: 0.7342 - recall: 0.6103
# Epoch 68/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3219 - accuracy: 0.8501 - precision: 0.7438 - recall: 0.6137
# Epoch 69/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3237 - accuracy: 0.8473 - precision: 0.7430 - recall: 0.5979
# Epoch 70/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3266 - accuracy: 0.8465 - precision: 0.7420 - recall: 0.5947
# Epoch 71/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3322 - accuracy: 0.8462 - precision: 0.7437 - recall: 0.5902
# Epoch 72/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3333 - accuracy: 0.8413 - precision: 0.7312 - recall: 0.5803
# Epoch 73/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3321 - accuracy: 0.8503 - precision: 0.7447 - recall: 0.6131
# Epoch 74/100
# 632/632 [==============================] - 1s 2ms/step - loss: 0.3182 - accuracy: 0.8509 - precision: 0.7479 - recall: 0.6117
# Epoch 75/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3362 - accuracy: 0.8422 - precision: 0.7278 - recall: 0.5925
# Epoch 76/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3240 - accuracy: 0.8472 - precision: 0.7404 - recall: 0.6020
# Epoch 77/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3153 - accuracy: 0.8544 - precision: 0.7515 - recall: 0.6267
# Epoch 78/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3191 - accuracy: 0.8520 - precision: 0.7504 - recall: 0.6144
# Epoch 79/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3168 - accuracy: 0.8510 - precision: 0.7434 - recall: 0.6202
# Epoch 80/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3302 - accuracy: 0.8413 - precision: 0.7247 - recall: 0.5925
# Epoch 81/100
# 632/632 [==============================] - 1s 2ms/step - loss: 0.3211 - accuracy: 0.8489 - precision: 0.7385 - recall: 0.6156
# Epoch 82/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3256 - accuracy: 0.8489 - precision: 0.7406 - recall: 0.6119
# Epoch 83/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3601 - accuracy: 0.8497 - precision: 0.7451 - recall: 0.6091
# Epoch 84/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3250 - accuracy: 0.8498 - precision: 0.7457 - recall: 0.6087
# Epoch 85/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3196 - accuracy: 0.8510 - precision: 0.7475 - recall: 0.6133
# Epoch 86/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3193 - accuracy: 0.8509 - precision: 0.7405 - recall: 0.6243
# Epoch 87/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3182 - accuracy: 0.8517 - precision: 0.7456 - recall: 0.6206
# Epoch 88/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3212 - accuracy: 0.8519 - precision: 0.7480 - recall: 0.6174
# Epoch 89/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3301 - accuracy: 0.8494 - precision: 0.7483 - recall: 0.6018
# Epoch 90/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3986 - accuracy: 0.8418 - precision: 0.7264 - recall: 0.5925
# Epoch 91/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3244 - accuracy: 0.8479 - precision: 0.7379 - recall: 0.6101
# Epoch 92/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3238 - accuracy: 0.8495 - precision: 0.7465 - recall: 0.6054
# Epoch 93/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3593 - accuracy: 0.8491 - precision: 0.7439 - recall: 0.6075
# Epoch 94/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3404 - accuracy: 0.8479 - precision: 0.7400 - recall: 0.6066
# Epoch 95/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3207 - accuracy: 0.8512 - precision: 0.7444 - recall: 0.6196
# Epoch 96/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3243 - accuracy: 0.8516 - precision: 0.7547 - recall: 0.6052
# Epoch 97/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3247 - accuracy: 0.8510 - precision: 0.7455 - recall: 0.6160
# Epoch 98/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3220 - accuracy: 0.8508 - precision: 0.7447 - recall: 0.6164
# Epoch 99/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3410 - accuracy: 0.8493 - precision: 0.7434 - recall: 0.6095
# Epoch 100/100
# 632/632 [==============================] - 1s 1ms/step - loss: 0.3536 - accuracy: 0.8489 - precision: 0.7518 - recall: 0.5935
